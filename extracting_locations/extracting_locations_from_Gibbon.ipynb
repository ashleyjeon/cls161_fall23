# %% [markdown]
# # Extracting location names and data from Gibbon
#
# In this note book we will put together and practice a lot of skills we have learned so far this term. Starting with just the raw text files from Gibbon's Decline and Fall we will create a DataFrame containing location names, location counts, and location data.
#
# The code in this notebook may seem complex, but if you read through it carefully, you will likely understand what most of the code is doing.

# %% [markdown]
# ## Set-up

# %%
# install necessary libraries. The "%%capture" stops the notebook from printing
# out all the insall output. Remove if you need to trouble shoot.
# %%capture
# !pip install stanza
# Out:
# UsageError: Line magic function `%%capture` not found.

# %%
# install necessary libraries. The "%%capture" stops the notebook from printing
# out all the insall output. Remove if you need to trouble shoot.
# %%capture
# !pip install wget
# Out:
# UsageError: Line magic function `%%capture` not found.

# %%
# import necessary libraries
import os
import pandas as pd
import stanza
import json
import wget

# %% [markdown]
# ## NLP pipeline
# Now that all the necessary libraries have been installed and imported into our project, we need to set up our nlp pipeline. We will use [Stanza](https://stanfordnlp.github.io/stanza/).

# %%
# load stanza nlp pipeline that tokenizes and performs Named Entity Recognition
nlp_ner= stanza.Pipeline(lang='en', processors='tokenize, ner')
# Out:
# 2023-11-06 01:26:46 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# 2023-11-06 01:26:47 INFO: Loading these models for language: en (English):
# ================================
# | Processor | Package          |
# --------------------------------
# | tokenize  | combined         |
# | ner       | ontonotes_charlm |
# ================================
#
# 2023-11-06 01:26:47 INFO: Using device: cpu
# 2023-11-06 01:26:47 INFO: Loading: tokenize
# 2023-11-06 01:26:48 INFO: Loading: ner
# 2023-11-06 01:26:49 INFO: Done loading processors!

# %% [markdown]
# ## Load text data
# If you are using a **Colab Notebook** you will need to run the cell below to get the text files.
#
# Otherwise, you should have all of the text files for Gibbon's _Decline and Fall of the Roman Empire_ already downloaded from Canvas.

# %%
# load text files, Colab only
! git clone https://github.com/jdeen33/Gibbon_text.git
# Out:
# Cloning into 'Gibbon_text'...
# remote: Enumerating objects: 74, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 74 (delta 0), reused 0 (delta 0), pack-reused 71
# Receiving objects: 100% (74/74), 4.20 MiB | 16.93 MiB/s, done.

# %% [markdown]
# ## Extract location infromation from text file(s)

# %%
# create function that will take a text string as input and return a dictionary
# with locations and location counts from the text string
def get_locations_from_text(text):
    locations_dict = {}
    doc = nlp_ner(text)
    for sentence in doc.sentences:
        for token in sentence.tokens:
            if token.ner == 'S-GPE':
                if not token.text in locations_dict.keys():
                    locations_dict[token.text] = 1
                else:
                    locations_dict[token.text] += 1
            else:
                continue
    return locations_dict

# %% [markdown]
# You will need to choose which chapter you would like to extract locations from. For this example I will use Chapter 16.
#
# For **Colab** it will look something like this:
# `/content/Gibbon_text/gibbon_decline_volume1_chap16.txt`
#
# For **Jupyter** it will look something like this:
# `../text/gibbon_decline_and_fall/gibbon_decline_volume1_chap16.txt`

# %%
# identify the path to the text file you want to use
path_to_file = './Gibbon_text/gibbon_decline_volume1_chap10.txt' # <-- Insert path to chosen file

# %%
# read text from text file
with open(path_to_file, encoding='utf-8', mode='r') as f:
       text  = f.read()

# %%
# apply function to get locations and location counts
# this will take a few minutes
locations = get_locations_from_text(text)

# %%
# sanity check
locations
# Out:
# {'Italy': 15,
#  'Verona': 1,
#  'Rome': 27,
#  'Gaul': 1,
#  'Spain': 3,
#  'Scandinavia': 3,
#  'Ravenna': 3,
#  'Scythia': 1,
#  'Sweden': 4,
#  'Gothland': 1,
#  'Iceland': 1,
#  'Denmark': 1,
#  'Maetois': 1,
#  'Mithridates': 1,
#  'Prussia': 5,
#  'Carlscrona': 1,
#  'Pomerania': 2,
#  'Thorn': 1,
#  'Elbing': 1,
#  'Koningsberg': 1,
#  'Dantzic': 1,
#  'Mecklenburg': 1,
#  'Dacia': 3,
#  'Germany': 6,
#  'Poland': 1,
#  'Russia': 1,
#  'Finland': 1,
#  'Sarmatia': 2,
#  'Japan': 1,
#  'Ukraine': 4,
#  'Dniester': 1,
#  'Maesia': 3,
#  'Marcianopolis': 1,
#  'Philippopolis': 3,
#  'Thrace': 2,
#  'Pannonia': 2,
#  'Spoleto': 2,
#  'Westphalia': 1,
#  'Brunswick': 1,
#  'Luneburg': 1,
#  'Gallienus': 3,
#  'Tarragona': 1,
#  'Mauritania': 1,
#  'Suevi': 2,
#  'Lombardy': 1,
#  'Milan': 1,
#  'Macedonia': 1,
#  'Circassia': 1,
#  'Pityus': 2,
#  'Trebizond': 3,
#  'Colchis': 1,
#  'Pontus': 3,
#  'Chalcedon': 3,
#  'Bithynia': 3,
#  'Nicomedia': 2,
#  'Prusa': 1,
#  'Apamaea': 1,
#  'Cius': 1,
#  'Cyzicus': 3,
#  'Rhyndacus': 1,
#  'Heraclea': 1,
#  'Nice': 1,
#  'Greece': 4,
#  'Piraeus': 2,
#  'Athens': 7,
#  'Sulla': 1,
#  'Thebes': 1,
#  'Argos': 1,
#  'Corinth': 1,
#  'Sparta': 1,
#  'Sunium': 1,
#  'Epirus': 1,
#  'Anchialus': 1,
#  'Ephesus': 3,
#  'Armenia': 5,
#  'Persia': 6,
#  'Carrhae': 1,
#  'Edessa': 1,
#  'Antioch': 3,
#  'Syria': 3,
#  'Cilicia': 3,
#  'Cappadocia': 2,
#  'Chalcis': 1,
#  'Tarsus': 1,
#  'Caesarea': 1,
#  'Palmyra': 2,
#  'Egypt': 3,
#  'Arras': 1,
#  'Illyricum': 1,
#  'Isauria': 2,
#  'Trebellianus': 1,
#  'Piso': 1,
#  'Thessaly': 1,
#  'Valens': 1,
#  'Achaia': 1,
#  'Aemilianus': 1,
#  'Celsus': 1,
#  'Sicily': 4,
#  'Alexandria': 8,
#  'Arabia': 1,
#  'India': 1,
#  'Bruchion': 1}

# %%
# you may want to save the locations dictionary
path = './' # <-- Path of your choosing
file_name = 'locations_data.json'
with open(file_name, encoding='utf-8', mode='w') as f:
    json.dump(locations, f)

# %%
# convert dictionary to dataframe for easier processing
location_count_df = pd.DataFrame.from_dict(locations, orient='index').reset_index().rename(columns={'index':'place_name', 0:'count'})

# %%
# preview DataFrame
location_count_df.head()
# Out:
#   place_name  count
# 0      Italy     15
# 1     Verona      1
# 2       Rome     27
# 3       Gaul      1
# 4      Spain      3

# %% [markdown]
# ## Load data from Pleiades

# %%
# data from Pleiades, thanks to Peter Nadel!
if not os.path.isfile('places.csv'):  # checkin to see if we have this file or not
    wget.download('https://raw.githubusercontent.com/pnadelofficial/FallDHCourseMaterials/main/places.csv')
if not os.path.isfile('names.csv'):
    wget.download('https://raw.githubusercontent.com/pnadelofficial/FallDHCourseMaterials/main/names.csv')

# %%
# load and preview places DataFrame
places_df = pd.read_csv('places.csv')
places_df.head()
# Out:
#                 created                                        description  \
# 0  2010-06-24T14:11:06Z  The ancient region known to the Romans as "Gal...
# 1  2020-01-10T20:52:00Z  A Roman house in Pompeii (I, 6, 15), also know...
# 2  2015-05-28T11:48:45Z  The so-called "House of the Lararium of Achill...
# 3  2020-03-20T15:26:53Z  A necropolis with inhumations dating to the fi...
# 4  2018-05-30T03:08:22Z  The megalithic defensive circuit of Rusellae d...
#
#                                              details  \
# 0   <p>The Barrington Atlas Directory notes: FRA</p>
# 1  <p>The house was excavated in 1913 and 1914. T...
# 2                                                NaN
# 3  <p>A necropolis located close to Monte Bibele ...
# 4                                                NaN
#
#                              provenance                              title  \
# 0  Barrington Atlas: BAtlas 1 D1 Gallia                             Gallia
# 1                              Pleiades                  House of the Ceii
# 2                              Pleiades  House of the Lararium of Achilles
# 3                              Pleiades         Monte Tamburino necropolis
# 4                              Pleiades           Circuit wall of Rusellae
#
#                                           uri         id  \
# 0        https://pleiades.stoa.org/places/993        993
# 1  https://pleiades.stoa.org/places/999909607  999909607
# 2  https://pleiades.stoa.org/places/999909608  999909608
# 3  https://pleiades.stoa.org/places/999917206  999917206
# 4  https://pleiades.stoa.org/places/999951524  999951524
#
#    representative_latitude  representative_longitude  \
# 0                46.705437                  1.013706
# 1                40.750010                 14.489506
# 2                40.750362                 14.489286
# 3                44.272322                 11.375880
# 4                42.829089                 11.163588
#
#                                     bounding_box_wkt
# 0  POLYGON ((8.672222 42.4395125, 8.672222 51.981...
# 1  POLYGON ((14.4895058 40.7500099, 14.4895058 40...
# 2  POLYGON ((14.489286 40.750362, 14.489286 40.75...
# 3  POLYGON ((11.3758803 44.2723222, 11.3758803 44...
# 4  POLYGON ((11.1635884 42.8290888, 11.1635884 42...

# %%
# load and preview names DataFrame
names_df = pd.read_csv('names.csv')
names_df.head()
# Out:
#                 created description details  \
# 0  2010-06-24T14:11:06Z         NaN     NaN
# 1  2010-06-24T14:11:07Z         NaN     NaN
# 2  2015-06-23T17:19:22Z         NaN     NaN
# 3  2017-06-26T23:54:15Z         NaN     NaN
# 4  2020-12-26T17:59:50Z         NaN     NaN
#
#                              provenance                       title  \
# 0  Barrington Atlas: BAtlas 1 D1 Gallia                      Gallia
# 1  Barrington Atlas: BAtlas 1 D1 Gallia                       Galli
# 2                              Pleiades           House of the Ceii
# 3                              Pleiades               Casa dei Ceii
# 4                              Pleiades  House of L. Ceius Secundus
#
#                                                  uri  \
# 0        https://pleiades.stoa.org/places/993/gallia
# 1         https://pleiades.stoa.org/places/993/galli
# 2  https://pleiades.stoa.org/places/999909607/nam...
# 3  https://pleiades.stoa.org/places/999909607/nam...
# 4  https://pleiades.stoa.org/places/999909607/hou...
#
#                            id   place_id   name_type language_tag  \
# 0                      gallia        993  geographic          NaN
# 1                       galli        993  geographic          NaN
# 2  name.2015-06-23.9071239510  999909607  geographic           en
# 3  name.2017-06-26.2201864114  999909607  geographic           it
# 4   house-of-l-ceius-secundus  999909607  geographic           en
#
#                 attested_form            romanized_form_1 romanized_form_2  \
# 0                         NaN                      Gallia              NaN
# 1                         NaN                       Galli              NaN
# 2           House of the Ceii           House of the Ceii              NaN
# 3               Casa dei Ceii               Casa dei Ceii              NaN
# 4  House of L. Ceius Secundus  House of L. Ceius Secundus              NaN
#
#   romanized_form_3 association_certainty transcription_accuracy  \
# 0              NaN               certain               accurate
# 1              NaN               certain               accurate
# 2              NaN               certain               accurate
# 3              NaN               certain               accurate
# 4              NaN               certain               accurate
#
#   transcription_completeness  year_after_which  year_before_which
# 0                   complete               NaN                NaN
# 1                   complete               NaN                NaN
# 2                   complete            1700.0             2100.0
# 3                   complete            1700.0             2100.0
# 4                   complete               NaN                NaN

# %%
# quick example: find 'Roma' in places DataFrame
places_df.loc[places_df['title'] == 'Roma']
# Out:
#                     created                                    description  \
# 21483  2018-06-07T19:48:13Z  The capital of the Roman Republic and Empire.
#
#                                                  details  \
# 21483  <p>The Barrington Atlas Directory notes: Roma/...
#
#                                 provenance title  \
# 21483  Barrington Atlas: BAtlas 43 B2 Roma  Roma
#
#                                            uri      id  \
# 21483  https://pleiades.stoa.org/places/423025  423025
#
#        representative_latitude  representative_longitude  \
# 21483                41.891775                 12.486137
#
#                                         bounding_box_wkt
# 21483  POLYGON ((12.486137 41.891775, 12.486137 41.89...

# %%
# quick example: find 'Rome' in names DataFrame
names_df.loc[names_df['romanized_form_1'] == 'Rome']
# Out:
#                     created                     description details  \
# 20810  2012-02-04T23:39:48Z  The modern English appellation     NaN
#
#                                 provenance title  \
# 20810  Barrington Atlas: BAtlas 43 B2 Roma  Rome
#
#                                                 uri    id  place_id  \
# 20810  https://pleiades.stoa.org/places/423025/rome  rome    423025
#
#         name_type language_tag attested_form romanized_form_1  \
# 20810  geographic           en          Rome             Rome
#
#       romanized_form_2 romanized_form_3 association_certainty  \
# 20810              NaN              NaN               certain
#
#       transcription_accuracy transcription_completeness  year_after_which  \
# 20810               accurate                   complete            1700.0
#
#        year_before_which
# 20810             2100.0

# %% [markdown]
# ## Extract data from Pleiades data
# For each location in we identified from the text, we will extract extract the longitude, latitude, and a description. First we need to find each location in the Pleiades data.

# %%
def get_pleiades_id(location):
    """
    Iterates through all of the possible names in the names.csv file
    Returns None if no matched names
    """
    name_row = names_df.loc[names_df['attested_form'] == location]
    if len(name_row) == 1:
        return int(name_row.place_id.iloc[0])
    else:
        name_row = names_df.loc[names_df['romanized_form_1'] == location]
        if len(name_row) == 1:
            return int(name_row.place_id.iloc[0])
        else:
            name_row = names_df.loc[names_df['romanized_form_2'] == location]
            if len(name_row) == 1:
                return int(name_row.place_id.iloc[0])
            else:
                name_row = names_df.loc[names_df['romanized_form_3'] == location]
                if len(name_row) == 1:
                    return int(name_row.place_id.iloc[0])
                else:
                    return None

# %%
# apply the above founction to each row in our location count DataFrame and then
# add a new colum with the Pleiades id
location_count_df['pleiades_id'] = location_count_df['place_name'].apply(get_pleiades_id)

# %%
# preview new location count DataFrame.
# the NaN means we were unable to find the location in the Pleiades data.
location_count_df.head()
# Out:
#   place_name  count  pleiades_id
# 0      Italy     15          NaN
# 1     Verona      1     383816.0
# 2       Rome     27     423025.0
# 3       Gaul      1          NaN
# 4      Spain      3          NaN

# %%
# we can drop the rows with NaN values
location_count_df = location_count_df.dropna().reset_index(drop=True)

# %%
# preview updated location count DataFrame
location_count_df.head()
# Out:
#       place_name  count  pleiades_id
# 0         Verona      1     383816.0
# 1           Rome     27     423025.0
# 2        Ravenna      3     393480.0
# 3       Sarmatia      2     825371.0
# 4  Marcianopolis      1     216878.0

# %% [markdown]
# Now that we have a `pleiades_id` for each location from names.csv, we can use that information to get more data from the places.csv. It would be possible to combine the functions below into one, but I have seperated them out for clarity.

# %%
def get_description(pleiades_id):
    """return description from a pleiades id"""
    places_row = places_df.loc[places_df['id'] == pleiades_id]
    if len(places_row) == 1:
        return places_row.description.iloc[0]

# %%
def get_uri(pleiades_id):
    """return uri from a pleiades id"""
    places_row = places_df.loc[places_df['id'] == pleiades_id]
    if len(places_row) == 1:
        return places_row.uri.iloc[0]

# %%
def get_latitude(pleiades_id):
    """return latitude from a pleiades id"""
    places_row = places_df.loc[places_df['id'] == pleiades_id]
    if len(places_row) == 1:
        return places_row.representative_latitude.iloc[0]

# %%
# Challenge: Can you write a function to get the longitude data?
def get_longitude(pleiades_id):
    """return longitude from a pleiades id"""
    places_row = places_df.loc[places_df['id'] == pleiades_id]
    if len(places_row) == 1:
        return places_row.representative_longitude.iloc[0]

# %%
# add new column for description
location_count_df['description'] = location_count_df['pleiades_id'].apply(get_description)

# %%
# Challenge: can you write the code to add a column for the uri?
location_count_df['uri'] = location_count_df['pleiades_id'].apply(get_uri)
location_count_df
# Out:
#        place_name  count  pleiades_id  \
# 0          Verona      1     383816.0
# 1            Rome     27     423025.0
# 2         Ravenna      3     393480.0
# 3        Sarmatia      2     825371.0
# 4   Marcianopolis      1     216878.0
# 5       Tarragona      1     246349.0
# 6           Milan      1     383706.0
# 7       Macedonia      1     491656.0
# 8       Trebizond      3     857359.0
# 9          Pontus      3     857287.0
# 10      Chalcedon      3     520988.0
# 11      Nicomedia      2     511337.0
# 12          Prusa      1     511384.0
# 13           Cius      1     216770.0
# 14        Cyzicus      3     511218.0
# 15       Heraclea      1     452333.0
# 16        Piraeus      2     580062.0
# 17         Athens      7     579885.0
# 18         Thebes      1     541138.0
# 19          Argos      1     570106.0
# 20        Corinth      1     570182.0
# 21         Sparta      1     570685.0
# 22         Epirus      1     530871.0
# 23      Anchialus      1     216702.0
# 24        Carrhae      1     658427.0
# 25        Cilicia      3     658440.0
# 26        Chalcis      1     540703.0
# 27        Palmyra      2     668331.0
# 28          Arras      1     109194.0
# 29      Illyricum      1     481865.0
# 30         Achaia      1     570028.0
# 31         Sicily      4     462492.0
# 32         Arabia      1     981506.0
# 33          India      1      50004.0
#
#                                           description  \
# 0   Verona was an ancient settlement that became a...
# 1       The capital of the Roman Republic and Empire.
# 2   A city of northern Adriatic Italy that served ...
# 3      An ancient place, cited: BAtlas 84 E3 Sarmatia
# 4   An ancient place, cited: BAtlas 22 E5 Marciano...
# 5   An Iberian site in contact with Greek and Phoe...
# 6   A Celtic settlement and crossroads, later a We...
# 7   The region of ancient Macedonia in the Balkan ...
# 8   An ancient settlement of Asia Minor on the sou...
# 9   A region of northeastern Anatolia consisting o...
# 10  Chalcedon was an ancient maritime city of Bith...
# 11  Nicomedia was founded in 712/11 BC as a Megari...
# 12  Settlement at Prusa began as a site called Ciu...
# 13         An ancient place, cited: BAtlas 22 F4 Cius
# 14             An ancient city of Mysia in Anatolia.
# 15     Heraclea was an ancient city of Magna Graecia.
# 16  The ancient, fortified port settlement (and de...
# 17  A major Greek city-state and the principal cit...
# 18  The ancient city of Thebes in Boeotia (modern ...
# 19  Argos was a city of ancient Greece that reache...
# 20  The ancient Greek and Roman city of Corinth, l...
# 21  Sparta was a prominent city-state (polis) of a...
# 22  An ancient region that included northwest part...
# 23    An ancient place, cited: BAtlas 22 E6 Anchialus
# 24  Carrhae is a major settlement of Upper Mesopot...
# 25  An ancient region, stretching along the southe...
# 26      An ancient place, cited: BAtlas 55 F4 Chalcis
# 27  An ancient oasis and trading city with monumen...
# 28  Nemetacum was the principal center of the Atre...
# 29  Illyricum was a Roman province that existed fr...
# 30  An ancient Greek region on the northern coast ...
# 31  Sicily is the largest island in the Mediterran...
# 32  A Roman province founded under Trajan shortly ...
# 33         An ancient place, cited: BAtlas 5 D2 India
#
#                                         uri
# 0   https://pleiades.stoa.org/places/383816
# 1   https://pleiades.stoa.org/places/423025
# 2   https://pleiades.stoa.org/places/393480
# 3   https://pleiades.stoa.org/places/825371
# 4   https://pleiades.stoa.org/places/216878
# 5   https://pleiades.stoa.org/places/246349
# 6   https://pleiades.stoa.org/places/383706
# 7   https://pleiades.stoa.org/places/491656
# 8   https://pleiades.stoa.org/places/857359
# 9   https://pleiades.stoa.org/places/857287
# 10  https://pleiades.stoa.org/places/520988
# 11  https://pleiades.stoa.org/places/511337
# 12  https://pleiades.stoa.org/places/511384
# 13  https://pleiades.stoa.org/places/216770
# 14  https://pleiades.stoa.org/places/511218
# 15  https://pleiades.stoa.org/places/452333
# 16  https://pleiades.stoa.org/places/580062
# 17  https://pleiades.stoa.org/places/579885
# 18  https://pleiades.stoa.org/places/541138
# 19  https://pleiades.stoa.org/places/570106
# 20  https://pleiades.stoa.org/places/570182
# 21  https://pleiades.stoa.org/places/570685
# 22  https://pleiades.stoa.org/places/530871
# 23  https://pleiades.stoa.org/places/216702
# 24  https://pleiades.stoa.org/places/658427
# 25  https://pleiades.stoa.org/places/658440
# 26  https://pleiades.stoa.org/places/540703
# 27  https://pleiades.stoa.org/places/668331
# 28  https://pleiades.stoa.org/places/109194
# 29  https://pleiades.stoa.org/places/481865
# 30  https://pleiades.stoa.org/places/570028
# 31  https://pleiades.stoa.org/places/462492
# 32  https://pleiades.stoa.org/places/981506
# 33   https://pleiades.stoa.org/places/50004

# %%
# add new column for latitude
location_count_df['latitude'] = location_count_df['pleiades_id'].apply(get_latitude)

# %%
# Challenge: can you write the code to add a column for the longitude?
location_count_df['longitude'] = location_count_df['pleiades_id'].apply(get_longitude)
location_count_df
# Out:
#        place_name  count  pleiades_id  \
# 0          Verona      1     383816.0
# 1            Rome     27     423025.0
# 2         Ravenna      3     393480.0
# 3        Sarmatia      2     825371.0
# 4   Marcianopolis      1     216878.0
# 5       Tarragona      1     246349.0
# 6           Milan      1     383706.0
# 7       Macedonia      1     491656.0
# 8       Trebizond      3     857359.0
# 9          Pontus      3     857287.0
# 10      Chalcedon      3     520988.0
# 11      Nicomedia      2     511337.0
# 12          Prusa      1     511384.0
# 13           Cius      1     216770.0
# 14        Cyzicus      3     511218.0
# 15       Heraclea      1     452333.0
# 16        Piraeus      2     580062.0
# 17         Athens      7     579885.0
# 18         Thebes      1     541138.0
# 19          Argos      1     570106.0
# 20        Corinth      1     570182.0
# 21         Sparta      1     570685.0
# 22         Epirus      1     530871.0
# 23      Anchialus      1     216702.0
# 24        Carrhae      1     658427.0
# 25        Cilicia      3     658440.0
# 26        Chalcis      1     540703.0
# 27        Palmyra      2     668331.0
# 28          Arras      1     109194.0
# 29      Illyricum      1     481865.0
# 30         Achaia      1     570028.0
# 31         Sicily      4     462492.0
# 32         Arabia      1     981506.0
# 33          India      1      50004.0
#
#                                           description  \
# 0   Verona was an ancient settlement that became a...
# 1       The capital of the Roman Republic and Empire.
# 2   A city of northern Adriatic Italy that served ...
# 3      An ancient place, cited: BAtlas 84 E3 Sarmatia
# 4   An ancient place, cited: BAtlas 22 E5 Marciano...
# 5   An Iberian site in contact with Greek and Phoe...
# 6   A Celtic settlement and crossroads, later a We...
# 7   The region of ancient Macedonia in the Balkan ...
# 8   An ancient settlement of Asia Minor on the sou...
# 9   A region of northeastern Anatolia consisting o...
# 10  Chalcedon was an ancient maritime city of Bith...
# 11  Nicomedia was founded in 712/11 BC as a Megari...
# 12  Settlement at Prusa began as a site called Ciu...
# 13         An ancient place, cited: BAtlas 22 F4 Cius
# 14             An ancient city of Mysia in Anatolia.
# 15     Heraclea was an ancient city of Magna Graecia.
# 16  The ancient, fortified port settlement (and de...
# 17  A major Greek city-state and the principal cit...
# 18  The ancient city of Thebes in Boeotia (modern ...
# 19  Argos was a city of ancient Greece that reache...
# 20  The ancient Greek and Roman city of Corinth, l...
# 21  Sparta was a prominent city-state (polis) of a...
# 22  An ancient region that included northwest part...
# 23    An ancient place, cited: BAtlas 22 E6 Anchialus
# 24  Carrhae is a major settlement of Upper Mesopot...
# 25  An ancient region, stretching along the southe...
# 26      An ancient place, cited: BAtlas 55 F4 Chalcis
# 27  An ancient oasis and trading city with monumen...
# 28  Nemetacum was the principal center of the Atre...
# 29  Illyricum was a Roman province that existed fr...
# 30  An ancient Greek region on the northern coast ...
# 31  Sicily is the largest island in the Mediterran...
# 32  A Roman province founded under Trajan shortly ...
# 33         An ancient place, cited: BAtlas 5 D2 India
#
#                                         uri  longitude   latitude
# 0   https://pleiades.stoa.org/places/383816  10.995736  45.442130
# 1   https://pleiades.stoa.org/places/423025  12.486137  41.891775
# 2   https://pleiades.stoa.org/places/393480  12.196604  44.415718
# 3   https://pleiades.stoa.org/places/825371  39.500000  45.500000
# 4   https://pleiades.stoa.org/places/216878  27.585033  43.225040
# 5   https://pleiades.stoa.org/places/246349   1.258338  41.116892
# 6   https://pleiades.stoa.org/places/383706   9.188060  45.463746
# 7   https://pleiades.stoa.org/places/491656  21.750000  41.250000
# 8   https://pleiades.stoa.org/places/857359  39.723312  41.004269
# 9   https://pleiades.stoa.org/places/857287  34.742551  43.078685
# 10  https://pleiades.stoa.org/places/520988  29.025789  40.983393
# 11  https://pleiades.stoa.org/places/511337  29.919887  40.765191
# 12  https://pleiades.stoa.org/places/511384  29.063819  40.182899
# 13  https://pleiades.stoa.org/places/216770  28.093520  44.777920
# 14  https://pleiades.stoa.org/places/511218  27.883191  40.385565
# 15  https://pleiades.stoa.org/places/452333  16.669885  40.211776
# 16  https://pleiades.stoa.org/places/580062  23.645032  37.937703
# 17  https://pleiades.stoa.org/places/579885  23.722746  37.972634
# 18  https://pleiades.stoa.org/places/541138  23.317577  38.319156
# 19  https://pleiades.stoa.org/places/570106  22.719464  37.631561
# 20  https://pleiades.stoa.org/places/570182  22.880841  37.906329
# 21  https://pleiades.stoa.org/places/570685  22.427298  37.077905
# 22  https://pleiades.stoa.org/places/530871  20.787702  39.546484
# 23  https://pleiades.stoa.org/places/216702  27.641374  42.555937
# 24  https://pleiades.stoa.org/places/658427  39.030038  36.864578
# 25  https://pleiades.stoa.org/places/658440  33.250000  36.250000
# 26  https://pleiades.stoa.org/places/540703  23.621937  38.457139
# 27  https://pleiades.stoa.org/places/668331  38.267072  34.551307
# 28  https://pleiades.stoa.org/places/109194   2.778586  50.292766
# 29  https://pleiades.stoa.org/places/481865  17.965028  42.427292
# 30  https://pleiades.stoa.org/places/570028  22.224586  38.102121
# 31  https://pleiades.stoa.org/places/462492  13.932018  37.643297
# 32  https://pleiades.stoa.org/places/981506  32.500000  27.500000
# 33   https://pleiades.stoa.org/places/50004  77.500000  22.500000

# %% [markdown]
# Now that we have all the data we need, I am going to make a few little changes to the DataFrame.

# %%
# now that we have a uri we don't need the pleiades_id
location_count_df = location_count_df.drop(columns=['pleiades_id'])

# %%
# for our purposes we don't really need an index, so I will make the place_name column the index
location_count_df.set_index('place_name', inplace=True)

# %%
# final sanity check
location_count_df
# Out:
#                count                                        description  \
# place_name
# Verona             1  Verona was an ancient settlement that became a...
# Rome              27      The capital of the Roman Republic and Empire.
# Ravenna            3  A city of northern Adriatic Italy that served ...
# Sarmatia           2     An ancient place, cited: BAtlas 84 E3 Sarmatia
# Marcianopolis      1  An ancient place, cited: BAtlas 22 E5 Marciano...
# Tarragona          1  An Iberian site in contact with Greek and Phoe...
# Milan              1  A Celtic settlement and crossroads, later a We...
# Macedonia          1  The region of ancient Macedonia in the Balkan ...
# Trebizond          3  An ancient settlement of Asia Minor on the sou...
# Pontus             3  A region of northeastern Anatolia consisting o...
# Chalcedon          3  Chalcedon was an ancient maritime city of Bith...
# Nicomedia          2  Nicomedia was founded in 712/11 BC as a Megari...
# Prusa              1  Settlement at Prusa began as a site called Ciu...
# Cius               1         An ancient place, cited: BAtlas 22 F4 Cius
# Cyzicus            3             An ancient city of Mysia in Anatolia.
# Heraclea           1     Heraclea was an ancient city of Magna Graecia.
# Piraeus            2  The ancient, fortified port settlement (and de...
# Athens             7  A major Greek city-state and the principal cit...
# Thebes             1  The ancient city of Thebes in Boeotia (modern ...
# Argos              1  Argos was a city of ancient Greece that reache...
# Corinth            1  The ancient Greek and Roman city of Corinth, l...
# Sparta             1  Sparta was a prominent city-state (polis) of a...
# Epirus             1  An ancient region that included northwest part...
# Anchialus          1    An ancient place, cited: BAtlas 22 E6 Anchialus
# Carrhae            1  Carrhae is a major settlement of Upper Mesopot...
# Cilicia            3  An ancient region, stretching along the southe...
# Chalcis            1      An ancient place, cited: BAtlas 55 F4 Chalcis
# Palmyra            2  An ancient oasis and trading city with monumen...
# Arras              1  Nemetacum was the principal center of the Atre...
# Illyricum          1  Illyricum was a Roman province that existed fr...
# Achaia             1  An ancient Greek region on the northern coast ...
# Sicily             4  Sicily is the largest island in the Mediterran...
# Arabia             1  A Roman province founded under Trajan shortly ...
# India              1         An ancient place, cited: BAtlas 5 D2 India
#
#                                                    uri  longitude   latitude
# place_name
# Verona         https://pleiades.stoa.org/places/383816  10.995736  45.442130
# Rome           https://pleiades.stoa.org/places/423025  12.486137  41.891775
# Ravenna        https://pleiades.stoa.org/places/393480  12.196604  44.415718
# Sarmatia       https://pleiades.stoa.org/places/825371  39.500000  45.500000
# Marcianopolis  https://pleiades.stoa.org/places/216878  27.585033  43.225040
# Tarragona      https://pleiades.stoa.org/places/246349   1.258338  41.116892
# Milan          https://pleiades.stoa.org/places/383706   9.188060  45.463746
# Macedonia      https://pleiades.stoa.org/places/491656  21.750000  41.250000
# Trebizond      https://pleiades.stoa.org/places/857359  39.723312  41.004269
# Pontus         https://pleiades.stoa.org/places/857287  34.742551  43.078685
# Chalcedon      https://pleiades.stoa.org/places/520988  29.025789  40.983393
# Nicomedia      https://pleiades.stoa.org/places/511337  29.919887  40.765191
# Prusa          https://pleiades.stoa.org/places/511384  29.063819  40.182899
# Cius           https://pleiades.stoa.org/places/216770  28.093520  44.777920
# Cyzicus        https://pleiades.stoa.org/places/511218  27.883191  40.385565
# Heraclea       https://pleiades.stoa.org/places/452333  16.669885  40.211776
# Piraeus        https://pleiades.stoa.org/places/580062  23.645032  37.937703
# Athens         https://pleiades.stoa.org/places/579885  23.722746  37.972634
# Thebes         https://pleiades.stoa.org/places/541138  23.317577  38.319156
# Argos          https://pleiades.stoa.org/places/570106  22.719464  37.631561
# Corinth        https://pleiades.stoa.org/places/570182  22.880841  37.906329
# Sparta         https://pleiades.stoa.org/places/570685  22.427298  37.077905
# Epirus         https://pleiades.stoa.org/places/530871  20.787702  39.546484
# Anchialus      https://pleiades.stoa.org/places/216702  27.641374  42.555937
# Carrhae        https://pleiades.stoa.org/places/658427  39.030038  36.864578
# Cilicia        https://pleiades.stoa.org/places/658440  33.250000  36.250000
# Chalcis        https://pleiades.stoa.org/places/540703  23.621937  38.457139
# Palmyra        https://pleiades.stoa.org/places/668331  38.267072  34.551307
# Arras          https://pleiades.stoa.org/places/109194   2.778586  50.292766
# Illyricum      https://pleiades.stoa.org/places/481865  17.965028  42.427292
# Achaia         https://pleiades.stoa.org/places/570028  22.224586  38.102121
# Sicily         https://pleiades.stoa.org/places/462492  13.932018  37.643297
# Arabia         https://pleiades.stoa.org/places/981506  32.500000  27.500000
# India           https://pleiades.stoa.org/places/50004  77.500000  22.500000

# %% [markdown]
# ## Save location data for further use

# %%
# create path and file name variables
path = os.getcwd() # <-- set path variable (not necessary for Colab)
file_name = 'location_data'# <-- set file_name variable

# %%
# save DataFrame to a .csv file
location_count_df.to_csv(file_name, index=False) # <-- For Jupyter you may want to add path

# %%
# Colab only
files.download(file_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 2
#       1 # Colab only
# ----> 2 files.download(file_name)
#
# NameError: name 'files' is not defined
